# %% [markdown]
# # Import

# %%
import sys

sys.path.append("../")
import datetime

from vook_db_v7.local_config import ClientId, pid, sid

aff_id = f"//ck.jp.ap.valuecommerce.com/servlet/referral?vs={sid}&vp={pid}&vc_url="

# import hashlib
import json

import pandas as pd
import requests
# Out:
# Now: Local env

# %% [markdown]
# # Global

# %%
REQ_URL_CATE = "https://shopping.yahooapis.jp/ShoppingWebService/V3/itemSearch"


PLATFORM = "Yahoo"
PLATFORM_ID = 2
BRAND = "リーバイス"
BRAND_ID = 1
ITEM = "デニム"
ITEM_ID = 1
LINE = "501"
LINE_ID = 1
KNOWLEDGE = "66前期"
KNOWLEDGE_ID = 1
START_AGE = 1974
END_AGE = 1977
AGES_ID = 1
RUN_TIME = datetime.datetime.today().strftime("%Y%m%d_%H%M%S")
INFO_GET_DATE = datetime.datetime.today()
TABLE_COLUMNS = [
    "product_id",
    "product_name",
    "platform_id",
    "ages_id",
    "brand_id",
    "item_id",
    "line_id",
    "price",
    "info_get_date",
    "status",
]

WANT_ITEMS = [
    "id",
    "name",
    "url",
    "price",
    "knowledge_id",
    "platform_id",
    "size_id",
    "created_at",
    "updated_at",
]

# %% [markdown]
# # Main

# %%
query = f"{BRAND} ヴィンテージ {ITEM} {LINE} {KNOWLEDGE}"

# %%
# 現在の日付と時刻を取得 & フォーマットを指定して文字列に変換
datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")
# Out:
# '2024-01-29 09:15:49.811883'

# %%
params = {
    "appid": ClientId,
    "output": "json",
    "query": query,
    "sort": "-price",
    "affiliate_id": aff_id,
    "affiliate_type": "vc",
    "results": 100,  # NOTE: 100個ずつしか取得できない。
}

start_num = 1
step = 100
max_products = 1000
l_df = []
for inc in range(0, max_products, step):
    params["start"] = start_num + inc
    df = pd.DataFrame(columns=WANT_ITEMS)
    res = requests.get(url=REQ_URL_CATE, params=params)
    res_cd = res.status_code
    if res_cd != 200:
        print(f"Bad request")
        break
    else:
        res = json.loads(res.text)
        if len(res["hits"]) == 0:
            print("If the number of returned items is 0, the loop ends.")
        print(f"Get Data")
        l_hit = []
        for h in res["hits"]:
            l_hit.append(
                (
                    h["index"],
                    h["name"],
                    h["url"],
                    h["price"],
                    KNOWLEDGE_ID,
                    PLATFORM_ID,
                    "",
                    # 現在の日付と時刻を取得 & フォーマットを指定して文字列に変換
                    datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f"),
                    # 現在の日付と時刻を取得 & フォーマットを指定して文字列に変換
                    datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f"),
                )
            )
        df = pd.DataFrame(l_hit, columns=WANT_ITEMS)
        l_df.append(df)
    break # NOTE: dev
# Out:
# Get Data

# %%
l_df[0].head()
# Out:
#    id                                               name  \
# 0   1  未使用品 リーバイス Levi's 501 66前期 70's ヴィンテージ デッドストック...
# 1   2  Levi's リーバイス 70s Vintage 501 66前期 赤耳 ストレートデニムパ...
# 2   3  Levi's リーバイス ヴィンテージ 501 66前期 ビックE トップボタン裏6 赤耳 ...
# 3   4  Levi's リーバイス ヴィンテージ 501 66前期 BIGE デニム パンツ インディ...
# 4   5  Levi's リーバイス ヴィンテージ 501 66前期 スモールE ボタンフライ ストレー...
#
#                                                  url   price  knowledge_id  \
# 0  https://ck.jp.ap.valuecommerce.com/servlet/ref...  600000             1
# 1  https://ck.jp.ap.valuecommerce.com/servlet/ref...  277200             1
# 2  https://ck.jp.ap.valuecommerce.com/servlet/ref...  241780             1
# 3  https://ck.jp.ap.valuecommerce.com/servlet/ref...  192379             1
# 4  https://ck.jp.ap.valuecommerce.com/servlet/ref...  120780             1
#
#    platform_id size_id                  created_at                  updated_at
# 0            2          2024-01-29 09:15:50.014161  2024-01-29 09:15:50.014198
# 1            2          2024-01-29 09:15:50.014209  2024-01-29 09:15:50.014216
# 2            2          2024-01-29 09:15:50.014223  2024-01-29 09:15:50.014229
# 3            2          2024-01-29 09:15:50.014236  2024-01-29 09:15:50.014242
# 4            2          2024-01-29 09:15:50.014248  2024-01-29 09:15:50.014254

# %%
products_raw = pd.concat(l_df, axis=0, ignore_index=True)

# %%
products_raw
# Out:
#      id                                               name  \
# 0     1  未使用品 リーバイス Levi's 501 66前期 70's ヴィンテージ デッドストック...
# 1     2  Levi's リーバイス 70s Vintage 501 66前期 赤耳 ストレートデニムパ...
# 2     3  Levi's リーバイス ヴィンテージ 501 66前期 ビックE トップボタン裏6 赤耳 ...
# 3     4  Levi's リーバイス ヴィンテージ 501 66前期 BIGE デニム パンツ インディ...
# 4     5  Levi's リーバイス ヴィンテージ 501 66前期 スモールE ボタンフライ ストレー...
# ..  ...                                                ...
# 95   96  Levis501 66前期 70sUSA製ビンテージ古着 ブルーデニムパンツ ダメージジーン...
# 96   97  LEVIS VINTAGE リーバイス ヴィンテージ ビンテージ オリジナル 501 66前...
# 97   98  【中古】LEVI'S 501 66前期 ヴィンテージ クラッシュデニム リーバイス 70s ...
# 98   99                中古 70'sLEVISリーバイス501/66前期/デニムパンツW38
# 99  100  Levi’s リーバイス 【YS2286G】 70's 70年代 501 デニムパンツ ジー...
#
#                                                   url   price  knowledge_id  \
# 0   https://ck.jp.ap.valuecommerce.com/servlet/ref...  600000             1
# 1   https://ck.jp.ap.valuecommerce.com/servlet/ref...  277200             1
# 2   https://ck.jp.ap.valuecommerce.com/servlet/ref...  241780             1
# 3   https://ck.jp.ap.valuecommerce.com/servlet/ref...  192379             1
# 4   https://ck.jp.ap.valuecommerce.com/servlet/ref...  120780             1
# ..                                                ...     ...           ...
# 95  https://ck.jp.ap.valuecommerce.com/servlet/ref...   22000             1
# 96  https://ck.jp.ap.valuecommerce.com/servlet/ref...   21978             1
# 97  https://ck.jp.ap.valuecommerce.com/servlet/ref...   21978             1
# 98  https://ck.jp.ap.valuecommerce.com/servlet/ref...   21978             1
# 99  https://ck.jp.ap.valuecommerce.com/servlet/ref...   21450             1
#
#     platform_id size_id                  created_at  \
# 0             2          2024-01-29 09:15:50.014161
# 1             2          2024-01-29 09:15:50.014209
# 2             2          2024-01-29 09:15:50.014223
# 3             2          2024-01-29 09:15:50.014236
# 4             2          2024-01-29 09:15:50.014248
# ..          ...     ...                         ...
# 95            2          2024-01-29 09:15:50.015383
# 96            2          2024-01-29 09:15:50.015395
# 97            2          2024-01-29 09:15:50.015408
# 98            2          2024-01-29 09:15:50.015420
# 99            2          2024-01-29 09:15:50.015433
#
#                     updated_at
# 0   2024-01-29 09:15:50.014198
# 1   2024-01-29 09:15:50.014216
# 2   2024-01-29 09:15:50.014229
# 3   2024-01-29 09:15:50.014242
# 4   2024-01-29 09:15:50.014254
# ..                         ...
# 95  2024-01-29 09:15:50.015389
# 96  2024-01-29 09:15:50.015401
# 97  2024-01-29 09:15:50.015414
# 98  2024-01-29 09:15:50.015426
# 99  2024-01-29 09:15:50.015438
#
# [100 rows x 9 columns]

# %%
# products_raw.to_csv(f"./data/output/products_raw.csv", index=False)
